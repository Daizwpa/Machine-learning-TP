# %% [markdown]
# # Instructions for setup python environment:

# %% [markdown]
# 1) [Download conda](https://www.anaconda.com/download):

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# or you can use this command on Windows powershell to download conda:
# ```
#  wget "https://repo.anaconda.com/miniconda/Miniconda3-latest-Windows-x86_64.exe" -outfile ".\miniconda.exe"
# ```

# %% [markdown]
# 2) Conda installation:

# %% [markdown]
# ![Conda-Installation-1.png](attachment:Conda-Installation-1.png)

# %% [markdown]
# ![Conda-Installation-4.jpg](attachment:Conda-Installation-4.jpg)

# %% [markdown]
# ![Conda-Installation-6.png](attachment:Conda-Installation-6.png)

# %% [markdown]
# 3) Make conda is accessible throught out the terminal.

# %% [markdown]
# search for application called Anaconda prompt

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4) bind anaconda environment with VS code

# %% [markdown]
# - Install python extension pack and jupyter extensions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5) create folder and open it using vs code and then create file with the extension .ipynb

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6) to select the interpreter just click at select kernel button
